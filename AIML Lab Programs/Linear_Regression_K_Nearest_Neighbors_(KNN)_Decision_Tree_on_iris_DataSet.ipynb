# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

display(df.head())
display(df.info())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
# None

# %%
X = df
y = iris.target

display(X.head())
display(y[:5])
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# array([0, 0, 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (105, 4)
# Shape of X_test: (45, 4)
# Shape of y_train: (105,)
# Shape of y_test: (45,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Instantiate the model
linear_reg_model = LinearRegression()

# Train the model
linear_reg_model.fit(X_train, y_train)

# Make predictions
y_pred_linear_reg = linear_reg_model.predict(X_test)

# Calculate evaluation metrics
mse_linear_reg = mean_squared_error(y_test, y_pred_linear_reg)
r2_linear_reg = r2_score(y_test, y_pred_linear_reg)

# Print the metrics
print(f"Linear Regression - Mean Squared Error: {mse_linear_reg:.4f}")
print(f"Linear Regression - R-squared Score: {r2_linear_reg:.4f}")
# Out:
# Linear Regression - Mean Squared Error: 0.0387
# Linear Regression - R-squared Score: 0.9442

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Instantiate the model
knn_model = KNeighborsClassifier(n_neighbors=5)

# Train the model
knn_model.fit(X_train, y_train)

# Make predictions
y_pred_knn = knn_model.predict(X_test)

# Calculate evaluation metrics
accuracy_knn = accuracy_score(y_test, y_pred_knn)
classification_rep_knn = classification_report(y_test, y_pred_knn)

# Print the metrics
print(f"K-Nearest Neighbors - Accuracy: {accuracy_knn:.4f}")
print("K-Nearest Neighbors - Classification Report:")
print(classification_rep_knn)
# Out:
# K-Nearest Neighbors - Accuracy: 1.0000
# K-Nearest Neighbors - Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the confusion matrix for KNN
conf_matrix_knn = confusion_matrix(y_test, y_pred_knn)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_knn, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - K-Nearest Neighbors')
plt.show()

# Print the accuracy again for easy comparison
print(f"K-Nearest Neighbors - Accuracy: {accuracy_knn:.4f}")
# Out:
# K-Nearest Neighbors - Accuracy: 1.0000

# %%
# Calculate the confusion matrix for Decision Tree
conf_matrix_decision_tree = confusion_matrix(y_test, y_pred_decision_tree)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_decision_tree, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Decision Tree')
plt.show()

# Print the accuracy again for easy comparison
print(f"Decision Tree - Accuracy: {accuracy_decision_tree:.4f}")
# Out:
# Decision Tree - Accuracy: 1.0000

# %% [markdown]
# ## Train and evaluate decision tree
#
# ### Subtask:
# Train a Decision Tree model and evaluate its performance.

# %% [markdown]
# **Reasoning**:
# Train a Decision Tree model and evaluate its performance by calculating the accuracy and generating a classification report.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Instantiate the model
decision_tree_model = DecisionTreeClassifier(random_state=42)

# Train the model
decision_tree_model.fit(X_train, y_train)

# Make predictions
y_pred_decision_tree = decision_tree_model.predict(X_test)

# Calculate evaluation metrics
accuracy_decision_tree = accuracy_score(y_test, y_pred_decision_tree)
classification_rep_decision_tree = classification_report(y_test, y_pred_decision_tree)

# Print the metrics
print(f"Decision Tree - Accuracy: {accuracy_decision_tree:.4f}")
print("Decision Tree - Classification Report:")
print(classification_rep_decision_tree)
# Out:
# Decision Tree - Accuracy: 1.0000
# Decision Tree - Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
print("--- Model Performance Summary ---")
print(f"Linear Regression:")
print(f"  Mean Squared Error (MSE): {mse_linear_reg:.4f}")
print(f"  R-squared Score: {r2_linear_reg:.4f}")
print("\nK-Nearest Neighbors:")
print(f"  Accuracy: {accuracy_knn:.4f}")
print("\nDecision Tree:")
print(f"  Accuracy: {accuracy_decision_tree:.4f}")
print("-------------------------------")
# Out:
# --- Model Performance Summary ---
# Linear Regression:
#   Mean Squared Error (MSE): 0.0387
#   R-squared Score: 0.9442
#
# K-Nearest Neighbors:
#   Accuracy: 1.0000
#
# Decision Tree:
#   Accuracy: 1.0000
# -------------------------------
